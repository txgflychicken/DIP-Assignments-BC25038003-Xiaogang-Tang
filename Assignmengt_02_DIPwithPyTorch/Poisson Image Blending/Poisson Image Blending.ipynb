# %%
import gradio as gr
from PIL import ImageDraw
import numpy as np
import torch
import torch.nn.functional as F
from PIL import Image
# Initialize the polygon state
def initialize_polygon():
    """
    Initializes the polygon state.

    Returns:
        dict: A dictionary with 'points' and 'closed' status.
    """
    return {'points': [], 'closed': False}

# Add a point to the polygon when the user clicks on the image
def add_point(img_original, polygon_state, evt: gr.SelectData):
    """
    Adds a point to the polygon based on user click event.

    Args:
        img_original (PIL.Image): The original image.
        polygon_state (dict): The current state of the polygon.
        evt (gr.SelectData): The click event data.

    Returns:
        tuple: Updated image with polygon and updated polygon state.
    """
    if polygon_state['closed']:
        return img_original, polygon_state  # Do not add points if polygon is closed

    x, y = evt.index
    polygon_state['points'].append((x, y))

    img_with_poly = img_original.copy()
    draw = ImageDraw.Draw(img_with_poly)

    # Draw lines between points
    if len(polygon_state['points']) > 1:
        draw.line(polygon_state['points'], fill='red', width=2)

    # Draw points
    for point in polygon_state['points']:
        draw.ellipse((point[0]-3, point[1]-3, point[0]+3, point[1]+3), fill='blue')

    return img_with_poly, polygon_state

# Close the polygon when the user clicks the "Close Polygon" button
def close_polygon(img_original, polygon_state):
    """
    Closes the polygon if there are at least three points.

    Args:
        img_original (PIL.Image): The original image.
        polygon_state (dict): The current state of the polygon.

    Returns:
        tuple: Updated image with closed polygon and updated polygon state.
    """
    if not polygon_state['closed'] and len(polygon_state['points']) > 2:
        polygon_state['closed'] = True
        img_with_poly = img_original.copy()
        draw = ImageDraw.Draw(img_with_poly)
        draw.polygon(polygon_state['points'], outline='red')
        return img_with_poly, polygon_state
    else:
        return img_original, polygon_state

# Update the background image by drawing the shifted polygon on it
def update_background(background_image_original, polygon_state, dx, dy):
    """
    Updates the background image by drawing the shifted polygon on it.

    Args:
        background_image_original (PIL.Image): The original background image.
        polygon_state (dict): The current state of the polygon.
        dx (int): Horizontal offset.
        dy (int): Vertical offset.

    Returns:
        PIL.Image: The updated background image with the polygon overlay.
    """
    if background_image_original is None:
        return None

    if polygon_state['closed']:
        img_with_poly = background_image_original.copy()
        draw = ImageDraw.Draw(img_with_poly)
        shifted_points = [(x + dx, y + dy) for x, y in polygon_state['points']]
        draw.polygon(shifted_points, outline='red')
        return img_with_poly
    else:
        return background_image_original

# Create a binary mask from polygon points
def create_mask_from_points(points, img_h, img_w):
    """
    Creates a binary mask from the given polygon points.

    Args:
        points (np.ndarray): Polygon points of shape (n, 2).
        img_h (int): Image height.
        img_w (int): Image width.

    Returns:
        np.ndarray: Binary mask of shape (img_h, img_w).
    """
    mask = np.zeros((img_h, img_w), dtype=np.uint8)
    ### FILL: Obtain Mask from Polygon Points. 
    ### 0 indicates outside the Polygon.
    ### 255 indicates inside the Polygon.
    # 使用 PIL 在 mask 上绘制填充多边形
    mask_img = Image.new('L', (img_w, img_h), 0)          # 创建单通道黑色图像
    draw = ImageDraw.Draw(mask_img)
    poly_points = [(int(p[0]), int(p[1])) for p in points]  # 将坐标转为整数元组
    draw.polygon(poly_points, fill=255)                    # 多边形内部填充白色(255)
    mask = np.array(mask_img, dtype=np.uint8)              # 转换回 numpy 数组
    return mask

# Calculate the Laplacian loss between the foreground and blended image
def cal_laplacian_loss(foreground_img, foreground_mask, blended_img, background_mask):
    """
    Computes the Laplacian loss between the foreground and blended images within the masks.

    Args:
        foreground_img (torch.Tensor): Foreground image tensor.
        foreground_mask (torch.Tensor): Foreground mask tensor.
        blended_img (torch.Tensor): Blended image tensor.
        background_mask (torch.Tensor): Background mask tensor.

    Returns:
        torch.Tensor: The computed Laplacian loss.
    """
    ### FILL: Compute Laplacian Loss with https://pytorch.org/docs/stable/generated/torch.nn.functional.conv2d.html.
    ### Note: The loss is computed within the masks.
    C = foreground_img.shape[1]  # 通道数

    # 四邻域拉普拉斯核
    laplacian_kernel = torch.tensor([[0., 1., 0.],
                                     [1., -4., 1.],
                                     [0., 1., 0.]], 
                                    device=foreground_img.device, dtype=foreground_img.dtype)
    weight = laplacian_kernel.reshape(1, 1, 3, 3).repeat(C, 1, 1, 1)

    # 计算拉普拉斯响应（各组独立卷积）
    fg_lap = F.conv2d(foreground_img, weight, groups=C, padding=1)
    bg_lap = F.conv2d(blended_img, weight, groups=C, padding=1)

    # 在掩码区域内取拉普拉斯值
    fg_mask_bool = foreground_mask.bool().expand(-1, C, -1, -1)
    bg_mask_bool = background_mask.bool().expand(-1, C, -1, -1)

    loss = F.mse_loss(bg_lap[bg_mask_bool], fg_lap[fg_mask_bool])

    return loss

# Perform Poisson image blending
def blending(foreground_image_original, background_image_original, dx, dy, polygon_state):
    """
    Blends the foreground polygon area onto the background image using Poisson blending.

    Args:
        foreground_image_original (PIL.Image): The original foreground image.
        background_image_original (PIL.Image): The original background image.
        dx (int): Horizontal offset.
        dy (int): Vertical offset.
        polygon_state (dict): The current state of the polygon.

    Returns:
        np.ndarray: The blended image as a numpy array.
    """
    if not polygon_state['closed'] or background_image_original is None or foreground_image_original is None:
        return background_image_original  # Return original background if conditions are not met

    # Convert images to numpy arrays
    foreground_np = np.array(foreground_image_original)
    background_np = np.array(background_image_original)

    # Get polygon points and shift them by dx and dy
    foreground_polygon_points = np.array(polygon_state['points']).astype(np.int64)
    background_polygon_points = foreground_polygon_points + np.array([int(dx), int(dy)]).reshape(1, 2)

    # Create masks from polygon points
    foreground_mask = create_mask_from_points(foreground_polygon_points, foreground_np.shape[0], foreground_np.shape[1])
    background_mask = create_mask_from_points(background_polygon_points, background_np.shape[0], background_np.shape[1])

    # Convert numpy arrays to torch tensors
    device = 'cuda:0' if torch.cuda.is_available() else 'cpu'  # Using CPU will be slow
    fg_img_tensor = torch.from_numpy(foreground_np).to(device).permute(2, 0, 1).unsqueeze(0).float() / 255.
    bg_img_tensor = torch.from_numpy(background_np).to(device).permute(2, 0, 1).unsqueeze(0).float() / 255.
    fg_mask_tensor = torch.from_numpy(foreground_mask).to(device).unsqueeze(0).unsqueeze(0).float() / 255.
    bg_mask_tensor = torch.from_numpy(background_mask).to(device).unsqueeze(0).unsqueeze(0).float() / 255.

    # Initialize blended image
    blended_img = bg_img_tensor.clone()
    mask_expanded = bg_mask_tensor.bool().expand(-1, 3, -1, -1)
    blended_img[mask_expanded] = blended_img[mask_expanded] * 0.9 + fg_img_tensor[fg_mask_tensor.bool().expand(-1, 3, -1, -1)] * 0.1
    blended_img.requires_grad = True

    # Set up optimizer
    optimizer = torch.optim.Adam([blended_img], lr=1e-2)

    # Optimization loop
    iter_num = 5000
    for step in range(iter_num):
        blended_img_for_loss = blended_img.detach() * (1. - bg_mask_tensor) + blended_img * bg_mask_tensor  # Only blending in the mask region

        loss = cal_laplacian_loss(fg_img_tensor, fg_mask_tensor, blended_img_for_loss, bg_mask_tensor)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 50 == 0:
            print(f'Optimize step: {step}, Laplacian distance loss: {loss.item()}')

        if step == int(iter_num*2/3): ### decrease learning rate at the half step
            optimizer.param_groups[0]['lr'] *= 0.1

    # Convert result back to numpy array
    result = torch.clamp(blended_img.detach(), 0, 1).cpu().permute(0, 2, 3, 1).squeeze().numpy() * 255
    result = result.astype(np.uint8)
    return result

# Helper function to close the polygon and reset dx
def close_polygon_and_reset_dx(img_original, polygon_state, dx, dy, background_image_original):
    """
    Closes the polygon, resets dx to 0, and updates the background image.

    Args:
        img_original (PIL.Image): The original image.
        polygon_state (dict): The current state of the polygon.
        dx (int): Horizontal offset.
        dy (int): Vertical offset.
        background_image_original (PIL.Image): The original background image.

    Returns:
        tuple: Updated image with polygon, updated polygon state, updated background image, and reset dx value.
    """
    # Close polygon
    img_with_poly, updated_polygon_state = close_polygon(img_original, polygon_state)

    # Reset dx value to 0
    new_dx = gr.update(value=0)

    # Update background image
    updated_background = update_background(background_image_original, updated_polygon_state, 0, dy)
    return img_with_poly, updated_polygon_state, updated_background, new_dx

# Gradio Interface
with gr.Blocks(title="Poisson Image Blending", css="""
    body {
        background-color: #1e1e1e;
        color: #ffffff;
    }
    .gr-button {
        font-size: 1em;
        padding: 0.75em 1.5em;
        border-radius: 8px;
        background-color: #6200ee;
        color: #ffffff;
        border: none;
    }
    .gr-button:hover {
        background-color: #3700b3;
    }
    .gr-slider input[type=range] {
        accent-color: #03dac6;
    }
    .gr-text, .gr-markdown {
        font-size: 1.1em;
    }
    .gr-markdown h1, .gr-markdown h2, .gr-markdown h3 {
        color: #bb86fc;
    }
    .gr-input, .gr-output {
        background-color: #2c2c2c;
        border: 1px solid #3c3c3c;
    }
""") as demo:
    # Initialize states
    polygon_state = gr.State(initialize_polygon())
    background_image_original = gr.State(value=None)

    # Title and description
    gr.Markdown("<h1 style='text-align: center;'>Poisson Image Blending</h1>")
    gr.Markdown("<p style='text-align: center; font-size: 1.2em;'>Blend a selected area from a foreground image onto a background image with adjustable positions.</p>")

    with gr.Row():
        with gr.Column():
            gr.Markdown("### Foreground Image")
            foreground_image_original = gr.Image(
                label="", type="pil", interactive=True, height=300
            )
            gr.Markdown(
                "<p style='font-size: 0.9em;'>Upload the foreground image where the polygon will be selected.</p>"
            )
            gr.Markdown("### Foreground Image with Polygon")
            foreground_image_with_polygon = gr.Image(
                label="", type="pil", interactive=True, height=300
            )
            gr.Markdown(
                "<p style='font-size: 0.9em;'>Click on the image to define the polygon area. After selecting at least three points, click <strong>Close Polygon</strong>.</p>"
            )
            close_polygon_button = gr.Button("Close Polygon")
        with gr.Column():
            gr.Markdown("### Background Image")
            background_image = gr.Image(
                label="", type="pil", interactive=True, height=300
            )
            gr.Markdown("<p style='font-size: 0.9em;'>Upload the background image where the polygon will be placed.</p>")

    with gr.Row():
        with gr.Column():
            gr.Markdown("### Background Image with Polygon Overlay")
            background_image_with_polygon = gr.Image(
                label="", type="pil", height=500
            )
            gr.Markdown("<p style='font-size: 0.9em;'>Adjust the position of the polygon using the sliders below.</p>")
        with gr.Column():
            gr.Markdown("### Blended Image")
            output_image = gr.Image(
                label="", type="pil", height=500  # Increased height for larger display
            )

    with gr.Row():
        with gr.Column():
            dx = gr.Slider(
                label="Horizontal Offset", minimum=-500, maximum=500, step=1, value=0
            )
        with gr.Column():
            dy = gr.Slider(
                label="Vertical Offset", minimum=-500, maximum=500, step=1, value=0
            )
        blend_button = gr.Button("Blend Images")

    # Interactions

    # Copy the original image to the interactive image when uploaded
    foreground_image_original.change(
        fn=lambda img: img,
        inputs=foreground_image_original,
        outputs=foreground_image_with_polygon,
    )

    # User interacts with the image with polygon
    foreground_image_with_polygon.select(
        add_point,
        inputs=[foreground_image_original, polygon_state],
        outputs=[foreground_image_with_polygon, polygon_state],
    )

    close_polygon_button.click(
        fn=close_polygon_and_reset_dx,
        inputs=[foreground_image_original, polygon_state, dx, dy, background_image_original],
        outputs=[foreground_image_with_polygon, polygon_state, background_image_with_polygon, dx],
    )

    background_image.change(
        fn=lambda img: img,
        inputs=background_image,
        outputs=background_image_original,
    )

    # Update background image when dx or dy changes
    dx.change(
        fn=update_background,
        inputs=[background_image_original, polygon_state, dx, dy],
        outputs=background_image_with_polygon,
    )
    dy.change(
        fn=update_background,
        inputs=[background_image_original, polygon_state, dx, dy],
        outputs=background_image_with_polygon,
    )

    # Blend images when button is clicked
    blend_button.click(
        fn=blending,
        inputs=[foreground_image_original, background_image_original, dx, dy, polygon_state],
        outputs=output_image,
    )

# Launch the Gradio app
demo.launch()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18344\227514165.py:252: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: css. Please pass these parameters to launch() instead.
#   with gr.Blocks(title="Poisson Image Blending", css="""
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Optimize step: 0, Laplacian distance loss: 0.018042171373963356
# Optimize step: 50, Laplacian distance loss: 0.0003465925110504031
# Optimize step: 100, Laplacian distance loss: 9.983425843529403e-05
# Optimize step: 150, Laplacian distance loss: 5.098512701806612e-05
# Optimize step: 200, Laplacian distance loss: 3.203429878340103e-05
# Optimize step: 250, Laplacian distance loss: 2.23213301069336e-05
# Optimize step: 300, Laplacian distance loss: 1.656386666581966e-05
# Optimize step: 350, Laplacian distance loss: 1.2867861187260132e-05
# Optimize step: 400, Laplacian distance loss: 1.0389909220975824e-05
# Optimize step: 450, Laplacian distance loss: 8.667196198075544e-06
# Optimize step: 500, Laplacian distance loss: 7.5308694249542896e-06
# Optimize step: 550, Laplacian distance loss: 6.735038823535433e-06
# Optimize step: 600, Laplacian distance loss: 6.236311946850037e-06
# Optimize step: 650, Laplacian distance loss: 5.948633315711049e-06
# Optimize step: 700, Laplacian distance loss: 5.740353572036838e-06
# Optimize step: 750, Laplacian distance loss: 5.521540515474044e-06
# Optimize step: 800, Laplacian distance loss: 5.565470473811729e-06
# Optimize step: 850, Laplacian distance loss: 4.983341568731703e-06
# Optimize step: 900, Laplacian distance loss: 4.886500846623676e-06
# Optimize step: 950, Laplacian distance loss: 4.978970082447631e-06
# Optimize step: 1000, Laplacian distance loss: 5.185695044929162e-06
# Optimize step: 1050, Laplacian distance loss: 4.482409167394508e-06
# Optimize step: 1100, Laplacian distance loss: 4.565809376799734e-06
# Optimize step: 1150, Laplacian distance loss: 4.858855390921235e-06
# Optimize step: 1200, Laplacian distance loss: 4.660378635890083e-06
# Optimize step: 1250, Laplacian distance loss: 4.15130080000381e-06
# Optimize step: 1300, Laplacian distance loss: 4.657069439417683e-06
# Optimize step: 1350, Laplacian distance loss: 4.566806637740228e-06
# Optimize step: 1400, Laplacian distance loss: 4.797029305336764e-06
# Optimize step: 1450, Laplacian distance loss: 4.494303084356943e-06
# Optimize step: 1500, Laplacian distance loss: 4.047550191899063e-06
# Optimize step: 1550, Laplacian distance loss: 4.043020908284234e-06
# Optimize step: 1600, Laplacian distance loss: 4.365937002148712e-06
# Optimize step: 1650, Laplacian distance loss: 4.660862487071427e-06
# Optimize step: 1700, Laplacian distance loss: 4.313880708650686e-06
# Optimize step: 1750, Laplacian distance loss: 4.516019089351175e-06
# Optimize step: 1800, Laplacian distance loss: 4.698702014138689e-06
# Optimize step: 1850, Laplacian distance loss: 3.91916273656534e-06
# Optimize step: 1900, Laplacian distance loss: 4.124452971154824e-06
# Optimize step: 1950, Laplacian distance loss: 3.72893305211619e-06
# Optimize step: 2000, Laplacian distance loss: 3.7317331589292735e-06
# Optimize step: 2050, Laplacian distance loss: 4.450429514690768e-06
# Optimize step: 2100, Laplacian distance loss: 4.666899258154444e-06
# Optimize step: 2150, Laplacian distance loss: 4.157158855377929e-06
# Optimize step: 2200, Laplacian distance loss: 3.865473900077632e-06
# Optimize step: 2250, Laplacian distance loss: 3.831472895399202e-06
# Optimize step: 2300, Laplacian distance loss: 4.020731921627885e-06
# Optimize step: 2350, Laplacian distance loss: 4.207845904602436e-06
# Optimize step: 2400, Laplacian distance loss: 4.341427484177984e-06
# Optimize step: 2450, Laplacian distance loss: 4.039975010527996e-06
# Optimize step: 2500, Laplacian distance loss: 3.720308086485602e-06
# Optimize step: 2550, Laplacian distance loss: 4.175391495664371e-06
# Optimize step: 2600, Laplacian distance loss: 4.2376291276013944e-06
# Optimize step: 2650, Laplacian distance loss: 4.369461748865433e-06
# Optimize step: 2700, Laplacian distance loss: 4.004545189673081e-06
# Optimize step: 2750, Laplacian distance loss: 4.272356818546541e-06
# Optimize step: 2800, Laplacian distance loss: 3.887974344252143e-06
# Optimize step: 2850, Laplacian distance loss: 4.2979249883501325e-06
# Optimize step: 2900, Laplacian distance loss: 3.834013568848604e-06
# Optimize step: 2950, Laplacian distance loss: 3.4933173083118163e-06
# Optimize step: 3000, Laplacian distance loss: 4.013206307718065e-06
# Optimize step: 3050, Laplacian distance loss: 4.308703864808194e-06
# Optimize step: 3100, Laplacian distance loss: 3.6999620078859152e-06
# Optimize step: 3150, Laplacian distance loss: 3.956502496293979e-06
# Optimize step: 3200, Laplacian distance loss: 3.88425860364805e-06
# Optimize step: 3250, Laplacian distance loss: 3.499915692373179e-06
# Optimize step: 3300, Laplacian distance loss: 4.372293460619403e-06
# Optimize step: 3350, Laplacian distance loss: 8.525385624125192e-07
# Optimize step: 3400, Laplacian distance loss: 5.378360015129147e-07
# Optimize step: 3450, Laplacian distance loss: 5.365722586248012e-07
# Optimize step: 3500, Laplacian distance loss: 5.356129122446873e-07
# Optimize step: 3550, Laplacian distance loss: 5.346445846043935e-07
# Optimize step: 3600, Laplacian distance loss: 5.336574986358755e-07
# Optimize step: 3650, Laplacian distance loss: 5.326517111825524e-07
# Optimize step: 3700, Laplacian distance loss: 5.316268811839109e-07
# Optimize step: 3750, Laplacian distance loss: 5.305830654833699e-07
# Optimize step: 3800, Laplacian distance loss: 5.295198093335785e-07
# Optimize step: 3850, Laplacian distance loss: 5.284375674818875e-07
# Optimize step: 3900, Laplacian distance loss: 5.273354872770142e-07
# Optimize step: 3950, Laplacian distance loss: 5.262136255623773e-07
# Optimize step: 4000, Laplacian distance loss: 5.250720391813957e-07
# Optimize step: 4050, Laplacian distance loss: 5.239102733867185e-07
# Optimize step: 4100, Laplacian distance loss: 5.227287260822777e-07
# Optimize step: 4150, Laplacian distance loss: 5.215266583036282e-07
# Optimize step: 4200, Laplacian distance loss: 5.203042974244454e-07
# Optimize step: 4250, Laplacian distance loss: 5.190615297578915e-07
# Optimize step: 4300, Laplacian distance loss: 5.177981279302912e-07
# Optimize step: 4350, Laplacian distance loss: 5.165139214113879e-07
# Optimize step: 4400, Laplacian distance loss: 5.152089670446003e-07
# Optimize step: 4450, Laplacian distance loss: 5.138832648299285e-07
# Optimize step: 4500, Laplacian distance loss: 5.12536644237116e-07
# Optimize step: 4550, Laplacian distance loss: 5.111688778924872e-07
# Optimize step: 4600, Laplacian distance loss: 5.097801931697177e-07
# Optimize step: 4650, Laplacian distance loss: 5.083704195385508e-07
# Optimize step: 4700, Laplacian distance loss: 5.069397275292431e-07
# Optimize step: 4750, Laplacian distance loss: 5.054877760812815e-07
# Optimize step: 4800, Laplacian distance loss: 5.040146220380848e-07
# Optimize step: 4850, Laplacian distance loss: 5.02520265399653e-07
# Optimize step: 4900, Laplacian distance loss: 5.010051040699182e-07
# Optimize step: 4950, Laplacian distance loss: 4.994686833015294e-07
# Optimize step: 0, Laplacian distance loss: 0.01765144057571888
# Optimize step: 50, Laplacian distance loss: 0.00033180337049998343
# Optimize step: 100, Laplacian distance loss: 9.46859727264382e-05
# Optimize step: 150, Laplacian distance loss: 4.821233596885577e-05
# Optimize step: 200, Laplacian distance loss: 3.0428023819695227e-05
# Optimize step: 250, Laplacian distance loss: 2.1440922864712775e-05
# Optimize step: 300, Laplacian distance loss: 1.614649227121845e-05
# Optimize step: 350, Laplacian distance loss: 1.273839188797865e-05
# Optimize step: 400, Laplacian distance loss: 1.0464703336765524e-05
# Optimize step: 450, Laplacian distance loss: 8.86269481270574e-06
# Optimize step: 500, Laplacian distance loss: 7.755013939458877e-06
# Optimize step: 550, Laplacian distance loss: 6.986940661590779e-06
# Optimize step: 600, Laplacian distance loss: 6.5804397308966145e-06
# Optimize step: 650, Laplacian distance loss: 6.2440972214972135e-06
# Optimize step: 700, Laplacian distance loss: 6.010660854371963e-06
# Optimize step: 750, Laplacian distance loss: 5.752925972046796e-06
# Optimize step: 800, Laplacian distance loss: 5.485389010573272e-06
# Optimize step: 850, Laplacian distance loss: 5.691079877578886e-06
# Optimize step: 900, Laplacian distance loss: 5.397988388722297e-06
# Optimize step: 950, Laplacian distance loss: 5.108319328428479e-06
# Optimize step: 1000, Laplacian distance loss: 4.851977337239077e-06
# Optimize step: 1050, Laplacian distance loss: 4.840516339754686e-06
# Optimize step: 1100, Laplacian distance loss: 4.789675131178228e-06
# Optimize step: 1150, Laplacian distance loss: 4.571563295030501e-06
# Optimize step: 1200, Laplacian distance loss: 4.520701168075902e-06
# Optimize step: 1250, Laplacian distance loss: 4.8178753786487505e-06
# Optimize step: 1300, Laplacian distance loss: 4.775753041030839e-06
# Optimize step: 1350, Laplacian distance loss: 4.282062491256511e-06
# Optimize step: 1400, Laplacian distance loss: 4.745956175611354e-06
# Optimize step: 1450, Laplacian distance loss: 4.480974439502461e-06
# Optimize step: 1500, Laplacian distance loss: 4.3362715587136336e-06
# Optimize step: 1550, Laplacian distance loss: 4.368895588413579e-06
# Optimize step: 1600, Laplacian distance loss: 4.622332653525518e-06
# Optimize step: 1650, Laplacian distance loss: 4.292695393814938e-06
# Optimize step: 1700, Laplacian distance loss: 3.668382760224631e-06
# Optimize step: 1750, Laplacian distance loss: 4.31149737778469e-06
# Optimize step: 1800, Laplacian distance loss: 4.098654244444333e-06
# Optimize step: 1850, Laplacian distance loss: 4.0334539335162845e-06
# Optimize step: 1900, Laplacian distance loss: 4.241328042553505e-06
# Optimize step: 1950, Laplacian distance loss: 3.8730499909434e-06
# Optimize step: 2000, Laplacian distance loss: 4.501001512835501e-06
# Optimize step: 2050, Laplacian distance loss: 4.770891791849863e-06
# Optimize step: 2100, Laplacian distance loss: 4.113385330128949e-06
# Optimize step: 2150, Laplacian distance loss: 4.022496341349324e-06
# Optimize step: 2200, Laplacian distance loss: 4.357078069006093e-06
# Optimize step: 2250, Laplacian distance loss: 4.002038167527644e-06
# Optimize step: 2300, Laplacian distance loss: 4.4024595808878075e-06
# Optimize step: 2350, Laplacian distance loss: 3.8144896734593203e-06
# Optimize step: 2400, Laplacian distance loss: 3.93508571505663e-06
# Optimize step: 2450, Laplacian distance loss: 4.358807927928865e-06
# Optimize step: 2500, Laplacian distance loss: 4.402583272167249e-06
# Optimize step: 2550, Laplacian distance loss: 3.718743073477526e-06
# Optimize step: 2600, Laplacian distance loss: 3.8094080991868395e-06
# Optimize step: 2650, Laplacian distance loss: 4.5544452405010816e-06
# Optimize step: 2700, Laplacian distance loss: 3.6948451906937407e-06
# Optimize step: 2750, Laplacian distance loss: 3.6955705127184046e-06
# Optimize step: 2800, Laplacian distance loss: 3.62908713213983e-06
# Optimize step: 2850, Laplacian distance loss: 3.8516363929375075e-06
# Optimize step: 2900, Laplacian distance loss: 4.2105330066988245e-06
# Optimize step: 2950, Laplacian distance loss: 4.199750947009306e-06
# Optimize step: 3000, Laplacian distance loss: 3.6529886529024225e-06
# Optimize step: 3050, Laplacian distance loss: 3.6744020235346397e-06
# Optimize step: 3100, Laplacian distance loss: 3.946295692003332e-06
# Optimize step: 3150, Laplacian distance loss: 4.2100641621800605e-06
# Optimize step: 3200, Laplacian distance loss: 3.6581375297828345e-06
# Optimize step: 3250, Laplacian distance loss: 3.92861693399027e-06
# Optimize step: 3300, Laplacian distance loss: 4.059022558067227e-06
# Optimize step: 3350, Laplacian distance loss: 8.876934316504048e-07
# Optimize step: 3400, Laplacian distance loss: 5.513056748895906e-07
# Optimize step: 3450, Laplacian distance loss: 5.499031772160379e-07
# Optimize step: 3500, Laplacian distance loss: 5.488325882652134e-07
# Optimize step: 3550, Laplacian distance loss: 5.477514832818997e-07
# Optimize step: 3600, Laplacian distance loss: 5.466495167638641e-07
# Optimize step: 3650, Laplacian distance loss: 5.455266887111065e-07
# Optimize step: 3700, Laplacian distance loss: 5.44383055967046e-07
# Optimize step: 3750, Laplacian distance loss: 5.432179932540748e-07
# Optimize step: 3800, Laplacian distance loss: 5.420318416327063e-07
# Optimize step: 3850, Laplacian distance loss: 5.408239189819142e-07
# Optimize step: 3900, Laplacian distance loss: 5.395945095187926e-07
# Optimize step: 3950, Laplacian distance loss: 5.383432721828285e-07
# Optimize step: 4000, Laplacian distance loss: 5.370699796003464e-07
# Optimize step: 4050, Laplacian distance loss: 5.357746886147652e-07
# Optimize step: 4100, Laplacian distance loss: 5.344568876353151e-07
# Optimize step: 4150, Laplacian distance loss: 5.331169745659281e-07
# Optimize step: 4200, Laplacian distance loss: 5.317541535987402e-07
# Optimize step: 4250, Laplacian distance loss: 5.303689931679401e-07
# Optimize step: 4300, Laplacian distance loss: 5.28960924839339e-07
# Optimize step: 4350, Laplacian distance loss: 5.275300622997747e-07
# Optimize step: 4400, Laplacian distance loss: 5.260762350189907e-07
# Optimize step: 4450, Laplacian distance loss: 5.245994429969869e-07
# Optimize step: 4500, Laplacian distance loss: 5.230993451732502e-07
# Optimize step: 4550, Laplacian distance loss: 5.215763962951314e-07
# Optimize step: 4600, Laplacian distance loss: 5.200300847718609e-07
# Optimize step: 4650, Laplacian distance loss: 5.18460637977114e-07
# Optimize step: 4700, Laplacian distance loss: 5.16867942224053e-07
# Optimize step: 4750, Laplacian distance loss: 5.152518838258402e-07
# Optimize step: 4800, Laplacian distance loss: 5.136127469995699e-07
# Optimize step: 4850, Laplacian distance loss: 5.11950190684729e-07
# Optimize step: 4900, Laplacian distance loss: 5.102646127852495e-07
# Optimize step: 4950, Laplacian distance loss: 5.085556153971993e-07
